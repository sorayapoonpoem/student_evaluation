# %%
#import library that need to use 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Social Innovation DS.csv')

# %%
df.head()
# Out:
#    School_group  Major_cat         School                  Major  Year  \
# 0             1          2  นวัตกรรมสังคม  การพัฒนาระหว่างประเทศ     4
# 1             1          2  นวัตกรรมสังคม  การพัฒนาระหว่างประเทศ     3
# 2             1          2  นวัตกรรมสังคม  การพัฒนาระหว่างประเทศ     3
# 3             1          2  นวัตกรรมสังคม  การพัฒนาระหว่างประเทศ     4
# 4             1          2  นวัตกรรมสังคม  การพัฒนาระหว่างประเทศ     3
#
#    Gender  Age  Close_friend  Closefriend_inout  GPAX  ... Learning_style_21  \
# 0       1   21             4                  1   3.9  ...                 4
# 1       1   21             2                  2   3.9  ...                 4
# 2       0   20             5                  1   3.9  ...                 4
# 3       1   22             1                  1   3.8  ...               999
# 4       1   22             5                  1   3.8  ...                 3
#
# ...

# %%
#use for identification data type
df.dtypes
# Out:
# School_group          int64
# Major_cat             int64
# School               object
# Major                object
# Year                  int64
#                       ...
# Learning_style_26     int64
# Learning_style_27     int64
# Learning_style_28     int64
# Learning_style_29     int64
# Learning_style_30     int64
# Length: 77, dtype: object

# %%
df.drop(['School', 'School_group', 'Major_cat', 'Major', 'Year', 'Gender', 'Age', 'Close_friend', 'Closefriend_inout', 'Health_status', 'Health_status_iden', 'Family_type', 'Recieve_care', 'Recieve_care_other', 'Family_income', 'Family_income', 'Family_income_enough', 'Studen_income', 'Student_income_enough', 'Dormitory', 'Relation_fam', 'Relation_friend', 'Relation_aj', 'Feel_uni_1', 'Feel_uni_2', 'Feel_uni_3','Feel_uni_4', 'Feel_uni_5', 'Feel_uni_6', 'Feel_envi_7', 'Feel_envi_8', 'Feel_envi_9', 'Feel_envi_10', 'Feel_envi_11', 'Feel_envi_12', 'Feel_envi_13', 'Feel_envi_14', 'Relax_activity', 'Problem', 'Problem_study', 'Problem_love', 'Problem_adjust', 'Problem_econ', 'Problem_other', 'Attitude', 'Attitude_iden'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    GPAX Rate  Learning_style_1  Learning_style_2  Learning_style_3  \
# 0   3.9    A                 3                 5                 4
# 1   3.9    A                 4                 4                 4
# 2   3.9    A                 4                 3                 3
# 3   3.8    A               999               999               999
# 4   3.8    A                 3                 4                 2
#
#    Learning_style_4  Learning_style_5  Learning_style_6  Learning_style_7  \
# 0                 3                 4                 5                 5
# 1                 3                 3                 2                 3
# 2                 4                 3                 4                 3
# 3               999               999               999               999
# 4                 1                 3                 2                 3
#
#    Learning_style_8  ...  Learning_style_21  Learning_style_22  \
# ...

# %%
#Displays data after drop columns
df.dtypes
# Out:
# GPAX                 float64
# Rate                  object
# Learning_style_1       int64
# Learning_style_2       int64
# Learning_style_3       int64
# Learning_style_4       int64
# Learning_style_5       int64
# Learning_style_6       int64
# Learning_style_7       int64
# Learning_style_8       int64
# Learning_style_9       int64
# Learning_style_10      int64
# Learning_style_11      int64
# Learning_style_12      int64
# Learning_style_13      int64
# Learning_style_14      int64
# Learning_style_15      int64
# Learning_style_16      int64
# Learning_style_17      int64
# Learning_style_18      int64
# Learning_style_19      int64
# Learning_style_20      int64
# Learning_style_21      int64
# Learning_style_22      int64
# Learning_style_23      int64
# Learning_style_24      int64
# Learning_style_25      int64
# Learning_style_26      int64
# Learning_style_27      int64
# Learning_style_28      int64
# Learning_style_29      int64
# Learning_style_30      int64
# ...

# %%
#Finding missing values for each feature
df.isnull().sum()
# Out:
# GPAX                 0
# Rate                 0
# Learning_style_1     0
# Learning_style_2     0
# Learning_style_3     0
# Learning_style_4     0
# Learning_style_5     0
# Learning_style_6     0
# Learning_style_7     0
# Learning_style_8     0
# Learning_style_9     0
# Learning_style_10    0
# Learning_style_11    0
# Learning_style_12    0
# Learning_style_13    0
# Learning_style_14    0
# Learning_style_15    0
# Learning_style_16    0
# Learning_style_17    0
# Learning_style_18    0
# Learning_style_19    0
# Learning_style_20    0
# Learning_style_21    0
# Learning_style_22    0
# Learning_style_23    0
# Learning_style_24    0
# Learning_style_25    0
# Learning_style_26    0
# Learning_style_27    0
# Learning_style_28    0
# Learning_style_29    0
# Learning_style_30    0
# dtype: int64

# %%
num_data = df.select_dtypes(include='number')
num_data.head()
# Out:
#    GPAX  Learning_style_1  Learning_style_2  Learning_style_3  \
# 0   3.9                 3                 5                 4
# 1   3.9                 4                 4                 4
# 2   3.9                 4                 3                 3
# 3   3.8               999               999               999
# 4   3.8                 3                 4                 2
#
#    Learning_style_4  Learning_style_5  Learning_style_6  Learning_style_7  \
# 0                 3                 4                 5                 5
# 1                 3                 3                 2                 3
# 2                 4                 3                 4                 3
# 3               999               999               999               999
# 4                 1                 3                 2                 3
#
#    Learning_style_8  Learning_style_9  ...  Learning_style_21  \
# 0                 5                 1  ...                  4
# ...

# %%
# get class
class_target = df.Rate

# %%
# Create box plots for all numeric features
fig, ax = plt.subplots(4, 8, figsize=(65, 45))
for i, subplot in zip(num_data.columns, ax.flatten()):
    sns.boxplot(num_data[i], ax=subplot)
# Out:
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\ASUS\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df.loc[df.Learning_style_1==999, 'Learning_style_1'] = 5.0
df.loc[df.Learning_style_2==999, 'Learning_style_2'] = 5.0
df.loc[df.Learning_style_3==999, 'Learning_style_3'] = 5.0
df.loc[df.Learning_style_4==999, 'Learning_style_4'] = 5.0
df.loc[df.Learning_style_5==999, 'Learning_style_5'] = 5.0
df.loc[df.Learning_style_6==999, 'Learning_style_6'] = 5.0
df.loc[df.Learning_style_7==999, 'Learning_style_7'] = 5.0
df.loc[df.Learning_style_8==999, 'Learning_style_8'] = 5.0
df.loc[df.Learning_style_9==999, 'Learning_style_9'] = 5.0
df.loc[df.Learning_style_10==999, 'Learning_style_10'] = 5.0
df.loc[df.Learning_style_11==999, 'Learning_style_11'] = 5.0
df.loc[df.Learning_style_12==999, 'Learning_style_12'] = 5.0
df.loc[df.Learning_style_13==999, 'Learning_style_13'] = 5.0
df.loc[df.Learning_style_14==999, 'Learning_style_14'] = 5.0
df.loc[df.Learning_style_15==999, 'Learning_style_15'] = 5.0
df.loc[df.Learning_style_16==999, 'Learning_style_16'] = 5.0
df.loc[df.Learning_style_17==999, 'Learning_style_17'] = 5.0
df.loc[df.Learning_style_18==999, 'Learning_style_18'] = 5.0
df.loc[df.Learning_style_19==999, 'Learning_style_19'] = 5.0
df.loc[df.Learning_style_20==999, 'Learning_style_20'] = 5.0
df.loc[df.Learning_style_21==999, 'Learning_style_21'] = 5.0
df.loc[df.Learning_style_22==999, 'Learning_style_22'] = 5.0
df.loc[df.Learning_style_23==999, 'Learning_style_23'] = 5.0
df.loc[df.Learning_style_24==999, 'Learning_style_24'] = 5.0
df.loc[df.Learning_style_25==999, 'Learning_style_25'] = 5.0
df.loc[df.Learning_style_26==999, 'Learning_style_26'] = 5.0
df.loc[df.Learning_style_27==999, 'Learning_style_27'] = 5.0
df.loc[df.Learning_style_28==999, 'Learning_style_28'] = 5.0
df.loc[df.Learning_style_29==999, 'Learning_style_29'] = 5.0
df.loc[df.Learning_style_30==999, 'Learning_style_30'] = 5.0
df
# Out:
#      GPAX Rate  Learning_style_1  Learning_style_2  Learning_style_3  \
# 0    3.90    A                 3                 5                 4
# 1    3.90    A                 4                 4                 4
# 2    3.90    A                 4                 3                 3
# 3    3.80    A                 5                 5                 5
# 4    3.80    A                 3                 4                 2
# ..    ...  ...               ...               ...               ...
# 123  1.98    E                 5                 5                 5
# 124  1.97    E                 3                 5                 4
# 125  1.87    E                 5                 5                 5
# 126  1.86    E                 4                 4                 4
# 127  1.30    E                 3                 5                 4
#
#      Learning_style_4  Learning_style_5  Learning_style_6  Learning_style_7  \
# ...

# %%
df.dtypes
# Out:
# GPAX                 float64
# Rate                  object
# Learning_style_1       int64
# Learning_style_2       int64
# Learning_style_3       int64
# Learning_style_4       int64
# Learning_style_5       int64
# Learning_style_6       int64
# Learning_style_7       int64
# Learning_style_8       int64
# Learning_style_9       int64
# Learning_style_10      int64
# Learning_style_11      int64
# Learning_style_12      int64
# Learning_style_13      int64
# Learning_style_14      int64
# Learning_style_15      int64
# Learning_style_16      int64
# Learning_style_17      int64
# Learning_style_18      int64
# Learning_style_19      int64
# Learning_style_20      int64
# Learning_style_21      int64
# Learning_style_22      int64
# Learning_style_23      int64
# Learning_style_24      int64
# Learning_style_25      int64
# Learning_style_26      int64
# Learning_style_27      int64
# Learning_style_28      int64
# Learning_style_29      int64
# Learning_style_30      int64
# ...

# %%
X = df.select_dtypes(include=['number'])
X
# Out:
#      GPAX  Learning_style_1  Learning_style_2  Learning_style_3  \
# 0    3.90                 3                 5                 4
# 1    3.90                 4                 4                 4
# 2    3.90                 4                 3                 3
# 3    3.80                 5                 5                 5
# 4    3.80                 3                 4                 2
# ..    ...               ...               ...               ...
# 123  1.98                 5                 5                 5
# 124  1.97                 3                 5                 4
# 125  1.87                 5                 5                 5
# 126  1.86                 4                 4                 4
# 127  1.30                 3                 5                 4
#
#      Learning_style_4  Learning_style_5  Learning_style_6  Learning_style_7  \
# 0                   3                 4                 5                 5
# ...

# %%
Y = class_target
Y
# Out:
# 0      A
# 1      A
# 2      A
# 3      A
# 4      A
#       ..
# 123    E
# 124    E
# 125    E
# 126    E
# 127    E
# Name: Rate, Length: 128, dtype: object

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X)
X = sc.transform(X)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# Initialize the knn model with k = 2
knn = KNeighborsClassifier(n_neighbors=2, metric = 'euclidean')

# Fit the model to the whole dataset
knn.fit(X, Y)

# Predict classes of training set
y_pred = knn.predict(X)

# Evaluate model performace
ac = metrics.accuracy_score(Y, y_pred)
print('Training Accuracy: ', ac)
# Out:
# Training Accuracy:  0.703125

# %%
# Import module from sklean to split data onto training and test sets
from sklearn.model_selection import train_test_split
# Split training set and test set with ration 70% : 30% by specify test_size = 0.2
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size = 0.2, stratify = Y, random_state = 0)

# print the shape of trainning and test sets
print("x_train shape: ", x_train.shape)
print("y_train shape: ", y_train.shape)
print("x_test shape: ", x_test.shape)
print("y_test shape: ", y_test.shape)
# Out:
# x_train shape:  (102, 31)
# y_train shape:  (102,)
# x_test shape:  (26, 31)
# y_test shape:  (26,)

# %%
Y.value_counts()
# Out:
# B    42
# C    32
# A    26
# D    23
# E     5
# Name: Rate, dtype: int64

# %%
y_train.value_counts()
# Out:
# B    33
# C    26
# A    21
# D    18
# E     4
# Name: Rate, dtype: int64

# %%
y_test.value_counts()
# Out:
# B    9
# C    6
# D    5
# A    5
# E    1
# Name: Rate, dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

# Initialize the knn model with k = 2
knn = KNeighborsClassifier(n_neighbors=2, metric = 'euclidean')

# Fit the model to the training set
knn.fit(x_train, y_train)

# Predict classes of the test set
y_pred = knn.predict(x_test)

# Evaluate model performace
ac = metrics.accuracy_score(y_test, y_pred)
print('Tesing Accuracy: ', ac)
# Out:
# Tesing Accuracy:  0.6153846153846154

# %%
#Step 1: Import the sklearn classes
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_validate

#Step 2: Create the model object with paramenters
#Create an instance of KNeighborsClassifier with k=2 
knn = KNeighborsClassifier(n_neighbors=2, metric = 'euclidean') 

#Step 3: Fit and test the model with cross validation (5-fold)
cv_results = cross_validate(knn, X,Y, cv=5, return_train_score=True)

# Accuracy score for each fold 
#print('Tesing Accuracy for each fold:', cv_results['test_score'])

# Overall accuracy score for cross validaiton 
print('Cross Validation Accuracy: %.3f +/- %.3f' % (cv_results['test_score'].mean(), cv_results['test_score'].std()))
# Out:
# Cross Validation Accuracy: 0.493 +/- 0.069

# %%
# Experimenting with different k values
from sklearn import metrics
k_range = list(range(1,31))
scores_cv = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k, metric = 'euclidean')
    cv_results = cross_validate(knn, X,Y, cv=5) # compute CV accuracy
    scores_cv.append(cv_results['test_score'].mean())
    print(k, cv_results['test_score'].mean())
# Out:
# 1 0.4683076923076923
# 2 0.4929230769230769
# 3 0.35907692307692307
# 4 0.4304615384615385
# 5 0.4064615384615385
# 6 0.3833846153846154
# 7 0.4144615384615385
# 8 0.3913846153846154
# 9 0.352
# 10 0.35169230769230764
# 11 0.31261538461538463
# 12 0.304
# 13 0.3046153846153846
# 14 0.2969230769230769
# 15 0.26584615384615384
# 16 0.2661538461538462
# 17 0.28215384615384614
# 18 0.3055384615384616
# 19 0.31323076923076926
# 20 0.30523076923076925
# 21 0.3129230769230769
# 22 0.27353846153846156
# 23 0.3046153846153846
# 24 0.28153846153846157
# 25 0.28153846153846157
# 26 0.29692307692307696
# 27 0.32
# 28 0.29692307692307696
# 29 0.27384615384615385
# 30 0.28923076923076924

# %%
# create a line graph for testing accuracy
import matplotlib.pyplot as plt
plt.plot(k_range, scores_cv, 'y', color='blue',marker='o', markerfacecolor='red', markersize='5')
plt.xlabel('k value ')
plt.ylabel('CV Accuracy Rate')
plt.title('CV Accuracy Rates of k (K-Nearest-Neighbors)')
plt.show()

# %%
# find best k with the highest cv accuracy
import operator
index, value = max(enumerate(scores_cv), key=operator.itemgetter(1))
print('best k = ', index+1, 'accuracy = ', value)
# Out:
# best k =  2 accuracy =  0.4929230769230769

# %%
#Step 1: Import the sklearn class
from sklearn.neighbors import KNeighborsClassifier

#Step 2: Create the model object with paramenters
#Create an instance of KNeighborsClassifier with k=2 (best k) 
best_knn = KNeighborsClassifier(n_neighbors=2, metric = 'euclidean') 

#Step 3: Fit the model with data (model training)
#Model is learning the relationship between data (X) and class(Y)
best_knn.fit(X,Y)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=2)

# %%
# Predict the class label for new record(s)
X_new = pd.read_csv('Social Innovation New sample.csv')
X_new.head()
# Out:
#    GPAX Rate  Learning_style_1  Learning_style_2  Learning_style_3  \
# 0  3.90    A                 3                 5                 3
# 1  3.90    A                 3                 3                 2
# 2  3.35    B                 3                 4                 3
# 3  3.30    B                 2                 2                 1
# 4  3.29    B                 4                 5                 4
#
#    Learning_style_4  Learning_style_5  Learning_style_6  Learning_style_7  \
# 0                 3                 4                 4                 5
# 1                 4                 4                 5                 3
# 2                 3                 3                 4                 5
# 3                 2                 2                 3                 5
# 4                 3                 4                 3                 2
#
#    Learning_style_8  ...  Learning_style_21  Learning_style_22  \
# ...

# %%
X_new = X_new.drop(columns=['Rate'])
X_new
# Out:
#     GPAX  Learning_style_1  Learning_style_2  Learning_style_3  \
# 0   3.90                 3                 5                 3
# 1   3.90                 3                 3                 2
# 2   3.35                 3                 4                 3
# 3   3.30                 2                 2                 1
# 4   3.29                 4                 5                 4
# 5   2.95                 4                 4                 4
# 6   2.86                 4                 3                 5
# 7   2.85                 4                 3                 4
# 8   2.43                 3                 4                 5
# 9   2.40                 4                 3                 4
# 10  2.40                 3                 4                 5
# 11  2.33                 1                 4                 4
# 12  2.32                 5                 5                 5
# 13  2.30                 3                 3                 4
# ...

# %%
X_new = sc.transform(X_new) # (2) normalize them using the normalization model created previously (sc is StandardScaler)
best_knn.predict(X_new) # (3) predict their class lables
# Out:
# array(['A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'A', 'B', 'D', 'B', 'B',
#        'C', 'D', 'C'], dtype=object)

# %%
import pickle 
pickle.dump(best_knn, open('best_knn.pkl', 'wb'))
pickle.dump(X, open('normalization.pkl', 'wb'))

# %%
import pickle
pickle.dump(best_knn.predict(X_new), open('model_name.pkl', 'wb'))
pickle.dump(X_new, open('normalization_model.pkl', 'wb'))
